# %%
# 載入資料與必要的套件
import pandas as pd
from pycaret.classification import *

# 讀取資料
train = pd.read_csv("./train.csv")
test = pd.read_csv("./test.csv")
train.head()

# 查看訓練資料集的前幾行
print("Train Dataset:")
print(train.head())

# 查看訓練資料集的前幾行
print("Train Dataset:")
print(train.head())

# 簡單處理缺失值與特徵工程
train['Age'] = train['Age'].fillna(train['Age'].median())
train['Embarked'] = train['Embarked'].fillna(train['Embarked'].mode()[0])
train['Fare'] = train['Fare'].fillna(train['Fare'].median())

# 處理測試集缺失值
test['Age'] = test['Age'].fillna(test['Age'].median())
test['Fare'] = test['Fare'].fillna(test['Fare'].median())

# 建立新特徵
train['FamilySize'] = train['SibSp'] + train['Parch']
test['FamilySize'] = test['SibSp'] + test['Parch']
train['IsAlone'] = (train['FamilySize'] == 1).astype(int)
test['IsAlone'] = (test['FamilySize'] == 1).astype(int)
# 刪除無用欄位
train.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)
test.drop(['Name', 'Ticket', 'Cabin'], axis=1, inplace=True)

# 將類別變數轉換為類別型
train['Sex'] = train['Sex'].astype('category')
train['Embarked'] = train['Embarked'].astype('category')
test['Sex'] = test['Sex'].astype('category')
test['Embarked'] = test['Embarked'].astype('category')

# 設定 PyCaret 環境
clf = setup(data=train,
            target='Survived',
            categorical_features=['Sex', 'Embarked'],
            session_id=123)

# 新增所需的庫
from sklearn.ensemble import GradientBoostingClassifier, AdaBoostClassifier

# 已存在的模型列表
models = [
    # 目前已使用的15個模型
]

# 添加新的模型到已存在的模型列表中
models.append(GradientBoostingClassifier())
models.append(AdaBoostClassifier())

# 比較所有模型
best_model = compare_models(n_select=16)  # 比較 16 種模型
# Out:
# Train Dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# Train Dataset:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S
# <style type="text/css">
# #T_bc7e9_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_bc7e9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bc7e9_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_bc7e9_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bc7e9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bc7e9_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_bc7e9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bc7e9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_bc7e9_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bc7e9_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_bc7e9_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bc7e9_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_bc7e9_row3_col1" class="data row3 col1" >(891, 11)</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bc7e9_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_bc7e9_row4_col1" class="data row4 col1" >(891, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bc7e9_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_bc7e9_row5_col1" class="data row5 col1" >(623, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bc7e9_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_bc7e9_row6_col1" class="data row6 col1" >(268, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bc7e9_row7_col0" class="data row7 col0" >Numeric features</td>
#       <td id="T_bc7e9_row7_col1" class="data row7 col1" >8</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bc7e9_row8_col0" class="data row8 col0" >Categorical features</td>
#       <td id="T_bc7e9_row8_col1" class="data row8 col1" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bc7e9_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_bc7e9_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bc7e9_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_bc7e9_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bc7e9_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_bc7e9_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bc7e9_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_bc7e9_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bc7e9_row13_col0" class="data row13 col0" >Maximum one-hot encoding</td>
#       <td id="T_bc7e9_row13_col1" class="data row13 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bc7e9_row14_col0" class="data row14 col0" >Encoding method</td>
#       <td id="T_bc7e9_row14_col1" class="data row14 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bc7e9_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_bc7e9_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bc7e9_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_bc7e9_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bc7e9_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_bc7e9_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_bc7e9_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_bc7e9_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_bc7e9_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_bc7e9_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_bc7e9_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_bc7e9_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_bc7e9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_bc7e9_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_bc7e9_row21_col1" class="data row21 col1" >86ee</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_6c379 th {
#   text-align: left;
# }
# #T_6c379_row0_col0, #T_6c379_row0_col2, #T_6c379_row0_col3, #T_6c379_row0_col4, #T_6c379_row1_col0, #T_6c379_row1_col1, #T_6c379_row1_col2, #T_6c379_row1_col3, #T_6c379_row1_col4, #T_6c379_row1_col5, #T_6c379_row1_col6, #T_6c379_row1_col7, #T_6c379_row2_col0, #T_6c379_row2_col1, #T_6c379_row2_col3, #T_6c379_row2_col5, #T_6c379_row2_col6, #T_6c379_row2_col7, #T_6c379_row3_col0, #T_6c379_row3_col1, #T_6c379_row3_col2, #T_6c379_row3_col3, #T_6c379_row3_col4, #T_6c379_row3_col5, #T_6c379_row3_col6, #T_6c379_row3_col7, #T_6c379_row4_col0, #T_6c379_row4_col1, #T_6c379_row4_col2, #T_6c379_row4_col3, #T_6c379_row4_col4, #T_6c379_row4_col5, #T_6c379_row4_col6, #T_6c379_row4_col7, #T_6c379_row5_col0, #T_6c379_row5_col1, #T_6c379_row5_col2, #T_6c379_row5_col3, #T_6c379_row5_col4, #T_6c379_row5_col5, #T_6c379_row5_col6, #T_6c379_row5_col7, #T_6c379_row6_col0, #T_6c379_row6_col1, #T_6c379_row6_col2, #T_6c379_row6_col3, #T_6c379_row6_col4, #T_6c379_row6_col5, #T_6c379_row6_col6, #T_6c379_row6_col7, #T_6c379_row7_col0, #T_6c379_row7_col1, #T_6c379_row7_col2, #T_6c379_row7_col3, #T_6c379_row7_col4, #T_6c379_row7_col5, #T_6c379_row7_col6, #T_6c379_row7_col7, #T_6c379_row8_col0, #T_6c379_row8_col1, #T_6c379_row8_col2, #T_6c379_row8_col3, #T_6c379_row8_col4, #T_6c379_row8_col5, #T_6c379_row8_col6, #T_6c379_row8_col7, #T_6c379_row9_col0, #T_6c379_row9_col1, #T_6c379_row9_col2, #T_6c379_row9_col3, #T_6c379_row9_col4, #T_6c379_row9_col5, #T_6c379_row9_col6, #T_6c379_row9_col7, #T_6c379_row10_col0, #T_6c379_row10_col1, #T_6c379_row10_col2, #T_6c379_row10_col3, #T_6c379_row10_col4, #T_6c379_row10_col5, #T_6c379_row10_col6, #T_6c379_row10_col7, #T_6c379_row11_col0, #T_6c379_row11_col1, #T_6c379_row11_col2, #T_6c379_row11_col3, #T_6c379_row11_col4, #T_6c379_row11_col5, #T_6c379_row11_col6, #T_6c379_row11_col7, #T_6c379_row12_col0, #T_6c379_row12_col1, #T_6c379_row12_col2, #T_6c379_row12_col4, #T_6c379_row12_col5, #T_6c379_row12_col6, #T_6c379_row12_col7, #T_6c379_row13_col0, #T_6c379_row13_col1, #T_6c379_row13_col2, #T_6c379_row13_col3, #T_6c379_row13_col4, #T_6c379_row13_col5, #T_6c379_row13_col6, #T_6c379_row13_col7, #T_6c379_row14_col0, #T_6c379_row14_col1, #T_6c379_row14_col2, #T_6c379_row14_col3, #T_6c379_row14_col4, #T_6c379_row14_col5, #T_6c379_row14_col6, #T_6c379_row14_col7, #T_6c379_row15_col0, #T_6c379_row15_col1, #T_6c379_row15_col2, #T_6c379_row15_col3, #T_6c379_row15_col4, #T_6c379_row15_col5, #T_6c379_row15_col6, #T_6c379_row15_col7 {
#   text-align: left;
# }
# #T_6c379_row0_col1, #T_6c379_row0_col5, #T_6c379_row0_col6, #T_6c379_row0_col7, #T_6c379_row2_col2, #T_6c379_row2_col4, #T_6c379_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6c379_row0_col8, #T_6c379_row1_col8, #T_6c379_row2_col8, #T_6c379_row3_col8, #T_6c379_row4_col8, #T_6c379_row5_col8, #T_6c379_row7_col8, #T_6c379_row8_col8, #T_6c379_row9_col8, #T_6c379_row10_col8, #T_6c379_row11_col8, #T_6c379_row12_col8, #T_6c379_row13_col8, #T_6c379_row14_col8, #T_6c379_row15_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6c379_row6_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6c379">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6c379_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_6c379_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_6c379_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_6c379_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_6c379_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_6c379_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_6c379_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_6c379_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_6c379_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c379_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_6c379_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_6c379_row0_col1" class="data row0 col1" >0.8153</td>
#       <td id="T_6c379_row0_col2" class="data row0 col2" >0.8413</td>
#       <td id="T_6c379_row0_col3" class="data row0 col3" >0.7239</td>
#       <td id="T_6c379_row0_col4" class="data row0 col4" >0.7807</td>
#       <td id="T_6c379_row0_col5" class="data row0 col5" >0.7499</td>
#       <td id="T_6c379_row0_col6" class="data row0 col6" >0.6041</td>
#       <td id="T_6c379_row0_col7" class="data row0 col7" >0.6063</td>
#       <td id="T_6c379_row0_col8" class="data row0 col8" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_6c379_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_6c379_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6c379_row1_col1" class="data row1 col1" >0.8105</td>
#       <td id="T_6c379_row1_col2" class="data row1 col2" >0.8370</td>
#       <td id="T_6c379_row1_col3" class="data row1 col3" >0.6986</td>
#       <td id="T_6c379_row1_col4" class="data row1 col4" >0.7846</td>
#       <td id="T_6c379_row1_col5" class="data row1 col5" >0.7362</td>
#       <td id="T_6c379_row1_col6" class="data row1 col6" >0.5897</td>
#       <td id="T_6c379_row1_col7" class="data row1 col7" >0.5943</td>
#       <td id="T_6c379_row1_col8" class="data row1 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_6c379_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_6c379_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_6c379_row2_col1" class="data row2 col1" >0.8073</td>
#       <td id="T_6c379_row2_col2" class="data row2 col2" >0.8567</td>
#       <td id="T_6c379_row2_col3" class="data row2 col3" >0.6861</td>
#       <td id="T_6c379_row2_col4" class="data row2 col4" >0.7879</td>
#       <td id="T_6c379_row2_col5" class="data row2 col5" >0.7292</td>
#       <td id="T_6c379_row2_col6" class="data row2 col6" >0.5816</td>
#       <td id="T_6c379_row2_col7" class="data row2 col7" >0.5881</td>
#       <td id="T_6c379_row2_col8" class="data row2 col8" >0.4390</td>
#     </tr>
#     <tr>
#       <th id="T_6c379_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_6c379_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_6c379_row3_col1" class="data row3 col1" >0.7976</td>
#       <td id="T_6c379_row3_col2" class="data row3 col2" >0.8298</td>
#       <td id="T_6c379_row3_col3" class="data row3 col3" >0.7366</td>
#       <td id="T_6c379_row3_col4" class="data row3 col4" >0.7415</td>
#       <td id="T_6c379_row3_col5" class="data row3 col5" >0.7341</td>
#       <td id="T_6c379_row3_col6" class="data row3 col6" >0.5715</td>
#       <td id="T_6c379_row3_col7" class="data row3 col7" >0.5764</td>
#       <td id="T_6c379_row3_col8" class="data row3 col8" >0.0390</td>
#     </tr>
#     <tr>
#       <th id="T_6c379_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_6c379_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_6c379_row4_col1" class="data row4 col1" >0.7960</td>
#       <td id="T_6c379_row4_col2" class="data row4 col2" >0.8519</td>
#       <td id="T_6c379_row4_col3" class="data row4 col3" >0.7072</td>
#       <td id="T_6c379_row4_col4" class="data row4 col4" >0.7506</td>
#       <td id="T_6c379_row4_col5" class="data row4 col5" >0.7235</td>
#       <td id="T_6c379_row4_col6" class="data row4 col6" >0.5630</td>
#       <td id="T_6c379_row4_col7" class="data row4 col7" >0.5679</td>
#       <td id="T_6c379_row4_col8" class="data row4 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_6c379_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_6c379_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_6c379_row5_col1" class="data row5 col1" >0.7912</td>
#       <td id="T_6c379_row5_col2" class="data row5 col2" >

# %%
# 2. 模型選擇與比較
# 使用 PyCaret 比較多個模型並選擇表現最好的幾個模型
top_models = compare_models(n_select=5)

# 集成多模型
blended_model = blend_models(top_models)

# 3. 超參數優化
tuned_model = tune_model(blended_model, optimize='Accuracy')

# 評估模型
evaluate_model(tuned_model)

# 最終化模型
final_model = finalize_model(tuned_model)

# 預測測試集
predictions = predict_model(final_model, data=test)

# 修復預測結果輸出
output_column = 'Label' if 'Label' in predictions.columns else 'prediction_label'
# Out:
# <style type="text/css">
# #T_ceccc th {
#   text-align: left;
# }
# #T_ceccc_row0_col0, #T_ceccc_row0_col2, #T_ceccc_row0_col3, #T_ceccc_row0_col4, #T_ceccc_row1_col0, #T_ceccc_row1_col1, #T_ceccc_row1_col2, #T_ceccc_row1_col3, #T_ceccc_row1_col4, #T_ceccc_row1_col5, #T_ceccc_row1_col6, #T_ceccc_row1_col7, #T_ceccc_row2_col0, #T_ceccc_row2_col1, #T_ceccc_row2_col3, #T_ceccc_row2_col5, #T_ceccc_row2_col6, #T_ceccc_row2_col7, #T_ceccc_row3_col0, #T_ceccc_row3_col1, #T_ceccc_row3_col2, #T_ceccc_row3_col3, #T_ceccc_row3_col4, #T_ceccc_row3_col5, #T_ceccc_row3_col6, #T_ceccc_row3_col7, #T_ceccc_row4_col0, #T_ceccc_row4_col1, #T_ceccc_row4_col2, #T_ceccc_row4_col3, #T_ceccc_row4_col4, #T_ceccc_row4_col5, #T_ceccc_row4_col6, #T_ceccc_row4_col7, #T_ceccc_row5_col0, #T_ceccc_row5_col1, #T_ceccc_row5_col2, #T_ceccc_row5_col3, #T_ceccc_row5_col4, #T_ceccc_row5_col5, #T_ceccc_row5_col6, #T_ceccc_row5_col7, #T_ceccc_row6_col0, #T_ceccc_row6_col1, #T_ceccc_row6_col2, #T_ceccc_row6_col3, #T_ceccc_row6_col4, #T_ceccc_row6_col5, #T_ceccc_row6_col6, #T_ceccc_row6_col7, #T_ceccc_row7_col0, #T_ceccc_row7_col1, #T_ceccc_row7_col2, #T_ceccc_row7_col3, #T_ceccc_row7_col4, #T_ceccc_row7_col5, #T_ceccc_row7_col6, #T_ceccc_row7_col7, #T_ceccc_row8_col0, #T_ceccc_row8_col1, #T_ceccc_row8_col2, #T_ceccc_row8_col3, #T_ceccc_row8_col4, #T_ceccc_row8_col5, #T_ceccc_row8_col6, #T_ceccc_row8_col7, #T_ceccc_row9_col0, #T_ceccc_row9_col1, #T_ceccc_row9_col2, #T_ceccc_row9_col3, #T_ceccc_row9_col4, #T_ceccc_row9_col5, #T_ceccc_row9_col6, #T_ceccc_row9_col7, #T_ceccc_row10_col0, #T_ceccc_row10_col1, #T_ceccc_row10_col2, #T_ceccc_row10_col3, #T_ceccc_row10_col4, #T_ceccc_row10_col5, #T_ceccc_row10_col6, #T_ceccc_row10_col7, #T_ceccc_row11_col0, #T_ceccc_row11_col1, #T_ceccc_row11_col2, #T_ceccc_row11_col3, #T_ceccc_row11_col4, #T_ceccc_row11_col5, #T_ceccc_row11_col6, #T_ceccc_row11_col7, #T_ceccc_row12_col0, #T_ceccc_row12_col1, #T_ceccc_row12_col2, #T_ceccc_row12_col4, #T_ceccc_row12_col5, #T_ceccc_row12_col6, #T_ceccc_row12_col7, #T_ceccc_row13_col0, #T_ceccc_row13_col1, #T_ceccc_row13_col2, #T_ceccc_row13_col3, #T_ceccc_row13_col4, #T_ceccc_row13_col5, #T_ceccc_row13_col6, #T_ceccc_row13_col7, #T_ceccc_row14_col0, #T_ceccc_row14_col1, #T_ceccc_row14_col2, #T_ceccc_row14_col3, #T_ceccc_row14_col4, #T_ceccc_row14_col5, #T_ceccc_row14_col6, #T_ceccc_row14_col7, #T_ceccc_row15_col0, #T_ceccc_row15_col1, #T_ceccc_row15_col2, #T_ceccc_row15_col3, #T_ceccc_row15_col4, #T_ceccc_row15_col5, #T_ceccc_row15_col6, #T_ceccc_row15_col7 {
#   text-align: left;
# }
# #T_ceccc_row0_col1, #T_ceccc_row0_col5, #T_ceccc_row0_col6, #T_ceccc_row0_col7, #T_ceccc_row2_col2, #T_ceccc_row2_col4, #T_ceccc_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_ceccc_row0_col8, #T_ceccc_row1_col8, #T_ceccc_row2_col8, #T_ceccc_row3_col8, #T_ceccc_row4_col8, #T_ceccc_row7_col8, #T_ceccc_row8_col8, #T_ceccc_row9_col8, #T_ceccc_row13_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_ceccc_row5_col8, #T_ceccc_row6_col8, #T_ceccc_row10_col8, #T_ceccc_row11_col8, #T_ceccc_row12_col8, #T_ceccc_row14_col8, #T_ceccc_row15_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_ceccc">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ceccc_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_ceccc_level0_col1" class="col_heading level0 col1" >Accuracy</th>
#       <th id="T_ceccc_level0_col2" class="col_heading level0 col2" >AUC</th>
#       <th id="T_ceccc_level0_col3" class="col_heading level0 col3" >Recall</th>
#       <th id="T_ceccc_level0_col4" class="col_heading level0 col4" >Prec.</th>
#       <th id="T_ceccc_level0_col5" class="col_heading level0 col5" >F1</th>
#       <th id="T_ceccc_level0_col6" class="col_heading level0 col6" >Kappa</th>
#       <th id="T_ceccc_level0_col7" class="col_heading level0 col7" >MCC</th>
#       <th id="T_ceccc_level0_col8" class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ceccc_level0_row0" class="row_heading level0 row0" >rf</th>
#       <td id="T_ceccc_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_ceccc_row0_col1" class="data row0 col1" >0.8153</td>
#       <td id="T_ceccc_row0_col2" class="data row0 col2" >0.8413</td>
#       <td id="T_ceccc_row0_col3" class="data row0 col3" >0.7239</td>
#       <td id="T_ceccc_row0_col4" class="data row0 col4" >0.7807</td>
#       <td id="T_ceccc_row0_col5" class="data row0 col5" >0.7499</td>
#       <td id="T_ceccc_row0_col6" class="data row0 col6" >0.6041</td>
#       <td id="T_ceccc_row0_col7" class="data row0 col7" >0.6063</td>
#       <td id="T_ceccc_row0_col8" class="data row0 col8" >0.0600</td>
#     </tr>
#     <tr>
#       <th id="T_ceccc_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_ceccc_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_ceccc_row1_col1" class="data row1 col1" >0.8105</td>
#       <td id="T_ceccc_row1_col2" class="data row1 col2" >0.8370</td>
#       <td id="T_ceccc_row1_col3" class="data row1 col3" >0.6986</td>
#       <td id="T_ceccc_row1_col4" class="data row1 col4" >0.7846</td>
#       <td id="T_ceccc_row1_col5" class="data row1 col5" >0.7362</td>
#       <td id="T_ceccc_row1_col6" class="data row1 col6" >0.5897</td>
#       <td id="T_ceccc_row1_col7" class="data row1 col7" >0.5943</td>
#       <td id="T_ceccc_row1_col8" class="data row1 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_ceccc_level0_row2" class="row_heading level0 row2" >catboost</th>
#       <td id="T_ceccc_row2_col0" class="data row2 col0" >CatBoost Classifier</td>
#       <td id="T_ceccc_row2_col1" class="data row2 col1" >0.8073</td>
#       <td id="T_ceccc_row2_col2" class="data row2 col2" >0.8567</td>
#       <td id="T_ceccc_row2_col3" class="data row2 col3" >0.6861</td>
#       <td id="T_ceccc_row2_col4" class="data row2 col4" >0.7879</td>
#       <td id="T_ceccc_row2_col5" class="data row2 col5" >0.7292</td>
#       <td id="T_ceccc_row2_col6" class="data row2 col6" >0.5816</td>
#       <td id="T_ceccc_row2_col7" class="data row2 col7" >0.5881</td>
#       <td id="T_ceccc_row2_col8" class="data row2 col8" >0.4730</td>
#     </tr>
#     <tr>
#       <th id="T_ceccc_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_ceccc_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_ceccc_row3_col1" class="data row3 col1" >0.7976</td>
#       <td id="T_ceccc_row3_col2" class="data row3 col2" >0.8298</td>
#       <td id="T_ceccc_row3_col3" class="data row3 col3" >0.7366</td>
#       <td id="T_ceccc_row3_col4" class="data row3 col4" >0.7415</td>
#       <td id="T_ceccc_row3_col5" class="data row3 col5" >0.7341</td>
#       <td id="T_ceccc_row3_col6" class="data row3 col6" >0.5715</td>
#       <td id="T_ceccc_row3_col7" class="data row3 col7" >0.5764</td>
#       <td id="T_ceccc_row3_col8" class="data row3 col8" >0.0350</td>
#     </tr>
#     <tr>
#       <th id="T_ceccc_level0_row4" class="row_heading level0 row4" >lr</th>
#       <td id="T_ceccc_row4_col0" class="data row4 col0" >Logistic Regression</td>
#       <td id="T_ceccc_row4_col1" class="data row4 col1" >0.7960</td>
#       <td id="T_ceccc_row4_col2" class="data row4 col2" >0.8519</td>
#       <td id="T_ceccc_row4_col3" class="data row4 col3" >0.7072</td>
#       <td id="T_ceccc_row4_col4" class="data row4 col4" >0.7506</td>
#       <td id="T_ceccc_row4_col5" class="data row4 col5" >0.7235</td>
#       <td id="T_ceccc_row4_col6" class="data row4 col6" >0.5630</td>
#       <td id="T_ceccc_row4_col7" class="data row4 col7" >0.5679</td>
#       <td id="T_ceccc_row4_col8" class="data row4 col8" >0.0440</td>
#     </tr>
#     <tr>
#       <th id="T_ceccc_level0_row5" class="row_heading level0 row5" >ridge</th>
#       <td id="T_ceccc_row5_col0" class="data row5 col0" >Ridge Classifier</td>
#       <td id="T_ceccc_row5_col1" class="data row5 col1" >0.7912</td>
#       <td id="T_ceccc_row5_col2" class="data row5 col2" >
# <style type="text/css">
# #T_2b6db_row10_col0, #T_2b6db_row10_col1, #T_2b6db_row10_col2, #T_2b6db_row10_col3, #T_2b6db_row10_col4, #T_2b6db_row10_col5, #T_2b6db_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_2b6db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2b6db_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_2b6db_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_2b6db_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_2b6db_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_2b6db_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_2b6db_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_2b6db_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2b6db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2b6db_row0_col0" class="data row0 col0" >0.8889</td>
#       <td id="T_2b6db_row0_col1" class="data row0 col1" >0.8868</td>
#       <td id="T_2b6db_row0_col2" class="data row0 col2" >0.7917</td>
#       <td id="T_2b6db_row0_col3" class="data row0 col3" >0.9048</td>
#       <td id="T_2b6db_row0_col4" class="data row0 col4" >0.8444</td>
#       <td id="T_2b6db_row0_col5" class="data row0 col5" >0.7586</td>
#       <td id="T_2b6db_row0_col6" class="data row0 col6" >0.7627</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2b6db_row1_col0" class="data row1 col0" >0.8254</td>
#       <td id="T_2b6db_row1_col1" class="data row1 col1" >0.8066</td>
#       <td id="T_2b6db_row1_col2" class="data row1 col2" >0.7500</td>
#       <td id="T_2b6db_row1_col3" class="data row1 col3" >0.7826</td>
#       <td id="T_2b6db_row1_col4" class="data row1 col4" >0.7660</td>
#       <td id="T_2b6db_row1_col5" class="data row1 col5" >0.6268</td>
#       <td id="T_2b6db_row1_col6" class="data row1 col6" >0.6272</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2b6db_row2_col0" class="data row2 col0" >0.8095</td>
#       <td id="T_2b6db_row2_col1" class="data row2 col1" >0.9316</td>
#       <td id="T_2b6db_row2_col2" class="data row2 col2" >0.7083</td>
#       <td id="T_2b6db_row2_col3" class="data row2 col3" >0.7727</td>
#       <td id="T_2b6db_row2_col4" class="data row2 col4" >0.7391</td>
#       <td id="T_2b6db_row2_col5" class="data row2 col5" >0.5896</td>
#       <td id="T_2b6db_row2_col6" class="data row2 col6" >0.5910</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2b6db_row3_col0" class="data row3 col0" >0.8387</td>
#       <td id="T_2b6db_row3_col1" class="data row3 col1" >0.8829</td>
#       <td id="T_2b6db_row3_col2" class="data row3 col2" >0.6957</td>
#       <td id="T_2b6db_row3_col3" class="data row3 col3" >0.8421</td>
#       <td id="T_2b6db_row3_col4" class="data row3 col4" >0.7619</td>
#       <td id="T_2b6db_row3_col5" class="data row3 col5" >0.6416</td>
#       <td id="T_2b6db_row3_col6" class="data row3 col6" >0.6483</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2b6db_row4_col0" class="data row4 col0" >0.7581</td>
#       <td id="T_2b6db_row4_col1" class="data row4 col1" >0.7763</td>
#       <td id="T_2b6db_row4_col2" class="data row4 col2" >0.5833</td>
#       <td id="T_2b6db_row4_col3" class="data row4 col3" >0.7368</td>
#       <td id="T_2b6db_row4_col4" class="data row4 col4" >0.6512</td>
#       <td id="T_2b6db_row4_col5" class="data row4 col5" >0.4698</td>
#       <td id="T_2b6db_row4_col6" class="data row4 col6" >0.4773</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2b6db_row5_col0" class="data row5 col0" >0.7742</td>
#       <td id="T_2b6db_row5_col1" class="data row5 col1" >0.8289</td>
#       <td id="T_2b6db_row5_col2" class="data row5 col2" >0.6250</td>
#       <td id="T_2b6db_row5_col3" class="data row5 col3" >0.7500</td>
#       <td id="T_2b6db_row5_col4" class="data row5 col4" >0.6818</td>
#       <td id="T_2b6db_row5_col5" class="data row5 col5" >0.5090</td>
#       <td id="T_2b6db_row5_col6" class="data row5 col6" >0.5141</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2b6db_row6_col0" class="data row6 col0" >0.9032</td>
#       <td id="T_2b6db_row6_col1" class="data row6 col1" >0.8849</td>
#       <td id="T_2b6db_row6_col2" class="data row6 col2" >0.8750</td>
#       <td id="T_2b6db_row6_col3" class="data row6 col3" >0.8750</td>
#       <td id="T_2b6db_row6_col4" class="data row6 col4" >0.8750</td>
#       <td id="T_2b6db_row6_col5" class="data row6 col5" >0.7961</td>
#       <td id="T_2b6db_row6_col6" class="data row6 col6" >0.7961</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2b6db_row7_col0" class="data row7 col0" >0.7742</td>
#       <td id="T_2b6db_row7_col1" class="data row7 col1" >0.8257</td>
#       <td id="T_2b6db_row7_col2" class="data row7 col2" >0.7917</td>
#       <td id="T_2b6db_row7_col3" class="data row7 col3" >0.6786</td>
#       <td id="T_2b6db_row7_col4" class="data row7 col4" >0.7308</td>
#       <td id="T_2b6db_row7_col5" class="data row7 col5" >0.5383</td>
#       <td id="T_2b6db_row7_col6" class="data row7 col6" >0.5430</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2b6db_row8_col0" class="data row8 col0" >0.7258</td>
#       <td id="T_2b6db_row8_col1" class="data row8 col1" >0.8476</td>
#       <td id="T_2b6db_row8_col2" class="data row8 col2" >0.5417</td>
#       <td id="T_2b6db_row8_col3" class="data row8 col3" >0.6842</td>
#       <td id="T_2b6db_row8_col4" class="data row8 col4" >0.6047</td>
#       <td id="T_2b6db_row8_col5" class="data row8 col5" >0.3991</td>
#       <td id="T_2b6db_row8_col6" class="data row8 col6" >0.4055</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2b6db_row9_col0" class="data row9 col0" >0.8548</td>
#       <td id="T_2b6db_row9_col1" class="data row9 col1" >0.9320</td>
#       <td id="T_2b6db_row9_col2" class="data row9 col2" >0.7917</td>
#       <td id="T_2b6db_row9_col3" class="data row9 col3" >0.8261</td>
#       <td id="T_2b6db_row9_col4" class="data row9 col4" >0.8085</td>
#       <td id="T_2b6db_row9_col5" class="data row9 col5" >0.6917</td>
#       <td id="T_2b6db_row9_col6" class="data row9 col6" >0.6921</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_2b6db_row10_col0" class="data row10 col0" >0.8153</td>
#       <td id="T_2b6db_row10_col1" class="data row10 col1" >0.8603</td>
#       <td id="T_2b6db_row10_col2" class="data row10 col2" >0.7154</td>
#       <td id="T_2b6db_row10_col3" class="data row10 col3" >0.7853</td>
#       <td id="T_2b6db_row10_col4" class="data row10 col4" >0.7463</td>
#       <td id="T_2b6db_row10_col5" class="data row10 col5" >0.6021</td>
#       <td id="T_2b6db_row10_col6" class="data row10 col6" >0.6057</td>
#     </tr>
#     <tr>
#       <th id="T_2b6db_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_2b6db_row11_col0" class="data row11 col0" >0.0548</td>
#       <td id="T_2b6db_row11_col1" class="data row11 col1" >0.0493</td>
#       <td id="T_2b6db_row11_col2" class="data row11 col2" >0.1002</td>
#       <td id="T_2b6db_row11_col3" class="data row11 col3" >0.0725</td>
#       <td id="T_2b6db_row11_col4
# <style type="text/css">
# #T_041a3_row10_col0, #T_041a3_row10_col1, #T_041a3_row10_col2, #T_041a3_row10_col3, #T_041a3_row10_col4, #T_041a3_row10_col5, #T_041a3_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_041a3">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_041a3_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_041a3_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_041a3_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_041a3_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_041a3_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_041a3_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_041a3_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_041a3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_041a3_row0_col0" class="data row0 col0" >0.8889</td>
#       <td id="T_041a3_row0_col1" class="data row0 col1" >0.8932</td>
#       <td id="T_041a3_row0_col2" class="data row0 col2" >0.7917</td>
#       <td id="T_041a3_row0_col3" class="data row0 col3" >0.9048</td>
#       <td id="T_041a3_row0_col4" class="data row0 col4" >0.8444</td>
#       <td id="T_041a3_row0_col5" class="data row0 col5" >0.7586</td>
#       <td id="T_041a3_row0_col6" class="data row0 col6" >0.7627</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_041a3_row1_col0" class="data row1 col0" >0.8413</td>
#       <td id="T_041a3_row1_col1" class="data row1 col1" >0.8205</td>
#       <td id="T_041a3_row1_col2" class="data row1 col2" >0.7917</td>
#       <td id="T_041a3_row1_col3" class="data row1 col3" >0.7917</td>
#       <td id="T_041a3_row1_col4" class="data row1 col4" >0.7917</td>
#       <td id="T_041a3_row1_col5" class="data row1 col5" >0.6635</td>
#       <td id="T_041a3_row1_col6" class="data row1 col6" >0.6635</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_041a3_row2_col0" class="data row2 col0" >0.8095</td>
#       <td id="T_041a3_row2_col1" class="data row2 col1" >0.9113</td>
#       <td id="T_041a3_row2_col2" class="data row2 col2" >0.7083</td>
#       <td id="T_041a3_row2_col3" class="data row2 col3" >0.7727</td>
#       <td id="T_041a3_row2_col4" class="data row2 col4" >0.7391</td>
#       <td id="T_041a3_row2_col5" class="data row2 col5" >0.5896</td>
#       <td id="T_041a3_row2_col6" class="data row2 col6" >0.5910</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_041a3_row3_col0" class="data row3 col0" >0.8387</td>
#       <td id="T_041a3_row3_col1" class="data row3 col1" >0.8740</td>
#       <td id="T_041a3_row3_col2" class="data row3 col2" >0.6957</td>
#       <td id="T_041a3_row3_col3" class="data row3 col3" >0.8421</td>
#       <td id="T_041a3_row3_col4" class="data row3 col4" >0.7619</td>
#       <td id="T_041a3_row3_col5" class="data row3 col5" >0.6416</td>
#       <td id="T_041a3_row3_col6" class="data row3 col6" >0.6483</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_041a3_row4_col0" class="data row4 col0" >0.7581</td>
#       <td id="T_041a3_row4_col1" class="data row4 col1" >0.7522</td>
#       <td id="T_041a3_row4_col2" class="data row4 col2" >0.5417</td>
#       <td id="T_041a3_row4_col3" class="data row4 col3" >0.7647</td>
#       <td id="T_041a3_row4_col4" class="data row4 col4" >0.6341</td>
#       <td id="T_041a3_row4_col5" class="data row4 col5" >0.4612</td>
#       <td id="T_041a3_row4_col6" class="data row4 col6" >0.4765</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_041a3_row5_col0" class="data row5 col0" >0.8226</td>
#       <td id="T_041a3_row5_col1" class="data row5 col1" >0.8355</td>
#       <td id="T_041a3_row5_col2" class="data row5 col2" >0.7083</td>
#       <td id="T_041a3_row5_col3" class="data row5 col3" >0.8095</td>
#       <td id="T_041a3_row5_col4" class="data row5 col4" >0.7556</td>
#       <td id="T_041a3_row5_col5" class="data row5 col5" >0.6173</td>
#       <td id="T_041a3_row5_col6" class="data row5 col6" >0.6207</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_041a3_row6_col0" class="data row6 col0" >0.9032</td>
#       <td id="T_041a3_row6_col1" class="data row6 col1" >0.8728</td>
#       <td id="T_041a3_row6_col2" class="data row6 col2" >0.8750</td>
#       <td id="T_041a3_row6_col3" class="data row6 col3" >0.8750</td>
#       <td id="T_041a3_row6_col4" class="data row6 col4" >0.8750</td>
#       <td id="T_041a3_row6_col5" class="data row6 col5" >0.7961</td>
#       <td id="T_041a3_row6_col6" class="data row6 col6" >0.7961</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_041a3_row7_col0" class="data row7 col0" >0.7742</td>
#       <td id="T_041a3_row7_col1" class="data row7 col1" >0.8235</td>
#       <td id="T_041a3_row7_col2" class="data row7 col2" >0.7917</td>
#       <td id="T_041a3_row7_col3" class="data row7 col3" >0.6786</td>
#       <td id="T_041a3_row7_col4" class="data row7 col4" >0.7308</td>
#       <td id="T_041a3_row7_col5" class="data row7 col5" >0.5383</td>
#       <td id="T_041a3_row7_col6" class="data row7 col6" >0.5430</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_041a3_row8_col0" class="data row8 col0" >0.7419</td>
#       <td id="T_041a3_row8_col1" class="data row8 col1" >0.8410</td>
#       <td id="T_041a3_row8_col2" class="data row8 col2" >0.5417</td>
#       <td id="T_041a3_row8_col3" class="data row8 col3" >0.7222</td>
#       <td id="T_041a3_row8_col4" class="data row8 col4" >0.6190</td>
#       <td id="T_041a3_row8_col5" class="data row8 col5" >0.4299</td>
#       <td id="T_041a3_row8_col6" class="data row8 col6" >0.4401</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_041a3_row9_col0" class="data row9 col0" >0.8548</td>
#       <td id="T_041a3_row9_col1" class="data row9 col1" >0.9057</td>
#       <td id="T_041a3_row9_col2" class="data row9 col2" >0.7917</td>
#       <td id="T_041a3_row9_col3" class="data row9 col3" >0.8261</td>
#       <td id="T_041a3_row9_col4" class="data row9 col4" >0.8085</td>
#       <td id="T_041a3_row9_col5" class="data row9 col5" >0.6917</td>
#       <td id="T_041a3_row9_col6" class="data row9 col6" >0.6921</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_041a3_row10_col0" class="data row10 col0" >0.8233</td>
#       <td id="T_041a3_row10_col1" class="data row10 col1" >0.8530</td>
#       <td id="T_041a3_row10_col2" class="data row10 col2" >0.7237</td>
#       <td id="T_041a3_row10_col3" class="data row10 col3" >0.7987</td>
#       <td id="T_041a3_row10_col4" class="data row10 col4" >0.7560</td>
#       <td id="T_041a3_row10_col5" class="data row10 col5" >0.6188</td>
#       <td id="T_041a3_row10_col6" class="data row10 col6" >0.6234</td>
#     </tr>
#     <tr>
#       <th id="T_041a3_level0_row11" class="row_heading level0 row11" >Std</th>
#       <td id="T_041a3_row11_col0" class="data row11 col0" >0.0507</td>
#       <td id="T_041a3_row11_col1" class="data row11 col1" >0.0460</td>
#       <td id="T_041a3_row11_col2" class="data row11 col2" >0.1044</td>
#       <td id="T_041a3_row11_col3" class="data row11 col3" >0.0648</td>
#       <td id="T_041a3_row11_col4
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Pipeline Plot', 'pipelin…
# Submission file saved as 'submission.csv'
